# %%
import os, sys
import pandas as pd
current_dir = os.getcwd()
parent_dir = os.path.dirname(current_dir)
sys.path.insert(0, parent_dir)
from scripts.preprocess import cleaning
from scripts.eda import EDA

# %%
df=cleaning.load_data('/Users/amantebeje/Desktop/projects/oil-price-analysis/Data/BrentOilPrices.csv')
df
# Out:
#               Date  Price
# 0        20-May-87  18.63
# 1        21-May-87  18.45
# 2        22-May-87  18.55
# 3        25-May-87  18.60
# 4        26-May-87  18.63
# ...            ...    ...
# 9006  Nov 08, 2022  96.85
# 9007  Nov 09, 2022  93.05
# 9008  Nov 10, 2022  94.25
# 9009  Nov 11, 2022  96.37
# 9010  Nov 14, 2022  93.59
#
# [9011 rows x 2 columns]

# %%
cleaning.check_missing_values(df)
# Out:
# Date     0
# Price    0
# dtype: int64

# %%
cleaning.check_duplicate_values(df)
# Out:
# np.int64(0)

# %%
cleaning.data_types(df)
# Out:
# Date      object
# Price    float64
# dtype: object

# %%
EDA.detect_outliers_with_boxplot(df)

# %%
EDA.lay(df)

# %%
EDA.trend_per_year(df)
# Out:
# /Users/amantebeje/Desktop/projects/oil-price-analysis/scripts/eda.py:7: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Date']=pd.to_datetime(df['Date'])

# %%
EDA.trend_per_month(df)

# %%
EDA.trend_per_day(df)
