# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os, sys
# Add the 'scripts' directory to the Python path for module imports
sys.path.append(os.path.abspath(os.path.join('..', 'scripts')))
from event_change import EventChangeAnalyzer

price_data = pd.read_csv('../Data/BrentOilPrices.csv')
price_data['Date'] = pd.to_datetime(price_data['Date'], format='mixed')
price_data.set_index('Date', inplace=True)
analyzer=EventChangeAnalyzer(price_data)

# %%
analyzer.calculate_cusum()

# %%
analyzer.detect_change_point()
# Out:
# Detected change point years: [1999, 2004, 2005, 2007, 2008, 2008, 2009, 2010, 2014, 2014, 2015, 2017, 2020, 2020, 2021, 2022]

# %%
change_point_date = analyzer.bayesian_change_point_detection()
# Out:
# Multiprocess sampling (4 chains in 4 jobs)
# CompoundStep
# >Metropolis: [change_point]
# >NUTS: [mu1, mu2, sigma1, sigma2]
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/rich/live.py:231: UserWarning:
# install "ipywidgets" for Jupyter support
#   warnings.warn('install "ipywidgets" for Jupyter support')
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling 4 chains for 2_000 tune and 4_000 draw iterations (8_000 + 16_000 draws total) took 5 seconds.
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# Bayesian sampling completed successfully.
# Estimated Change Point Date: 2004-03-03 00:00:00

# %%
key_events={
    'OPEC Cuts & Asian Economic Recovery':'1999-03-23',
    'Geopolitical Tensions':'2004-06-23',
    'Hurricanes & Supply Disruptions':'2005-08-29',
    'Rising Demand & Speculation':'2007-11-01',
    'Financial Crisis':'2008-07-11',
    'Oil Price Crash':'2008-11-18',
    'Post-Crisis Recovery':'2009-06-11',
    'Global Economic Recovery & BP Oil Spill':'2010-12-13',
    'ISIS insurgency in Iraq':'2014-06-19',
    'Oil Price Crash(2014)':'2014-11-28',
    'Continued Oversupply':'2015-01-12',
    'OPEC Production Cuts':'2017-01-03',
    'OPEC Production Cuts':'2017-01-03',
    'Russia-Saudi Arabia oil price war':'2020-03-09',
    'COVID-19 Pandemic':'2020-04-21',
    'OPEC+ production limits':'2021-07-19',
    'Russia-Ukraine War':'2022-03-01',
    
}

# %%
event_impact_df, t_test_df = analyzer.analyze_price_changes_around_events(key_events)

# Display results
print("Event Impact DataFrame:")
display(event_impact_df)

print("\nT-Test Results:")
display(t_test_df)
# Out:
#                                          t-statistic       p-value
# OPEC Cuts & Asian Economic Recovery       -23.017740  2.708379e-63
# Geopolitical Tensions                     -19.103329  4.868610e-51
# Hurricanes & Supply Disruptions            -8.628759  6.872953e-16
# Rising Demand & Speculation               -26.438642  7.545686e-74
# Financial Crisis                            9.778747  2.602026e-19
# Oil Price Crash                            22.816388  9.406352e-63
# Post-Crisis Recovery                      -25.564950  2.451723e-71
# Global Economic Recovery & BP Oil Spill   -27.208075  2.830226e-76
# ISIS insurgency in Iraq                    12.736641  5.985238e-29
# Oil Price Crash(2014)                      34.501844  7.557295e-97
# Continued Oversupply                       17.218588  2.396754e-44
# OPEC Production Cuts                       -9.388490  3.769456e-18
# Russia-Saudi Arabia oil price war          26.505305  7.756635e-75
# COVID-19 Pandemic                           8.603219  8.559213e-16
# OPEC+ production limits                   -14.198999  5.921297e-34
# Russia-Ukraine War                        -26.325212  4.970235e-74
# Event Impact DataFrame:
#                                       Event        Date  Change_1M  Change_3M  \
# 0       OPEC Cuts & Asian Economic Recovery  1999-03-23        NaN  57.820383
# 1                     Geopolitical Tensions  2004-06-23   0.943396  33.733493
# 2           Hurricanes & Supply Disruptions  2005-08-29        NaN        NaN
# 3               Rising Demand & Speculation  2007-11-01        NaN  22.691083
# 4                          Financial Crisis  2008-07-11        NaN        NaN
# 5                           Oil Price Crash  2008-11-18        NaN        NaN
# 6                      Post-Crisis Recovery  2009-06-11        NaN  55.125639
# 7   Global Economic Recovery & BP Oil Spill  2010-12-13        NaN        NaN
# 8                   ISIS insurgency in Iraq  2014-06-19        NaN  -8.861940
# 9                     Oil Price Crash(2014)  2014-11-28        NaN        NaN
# 10                     Continued Oversupply  2015-01-12        NaN        NaN
# 11                     OPEC Production Cuts  2017-01-03        NaN   4.982853
# 12        Russia-Saudi Arabia oil price war  2020-03-09        NaN        NaN
# 13                        COVID-19 Pandemic  2020-04-21        NaN -30.284978
# 14                  OPEC+ production limits  2021-07-19        NaN        NaN
# 15                       Russia-Ukraine War  2022-03-01        NaN  76.916439
#
#    Change_6M  Cumulative Return Before  Cumulative Return After
# 0       None                 -0.080863                 0.681085
# 1       None                  0.193349                 0.225797
# 2       None                  0.268756                -0.071638
# 3       None                  0.441148                 0.260071
# 4       None                  0.551955                -0.678243
# 5       None                 -0.619498                 0.147251
# 6       None                  0.592848                 0.044903
# 7       None                  0.187599                 0.313164
# 8       None                  0.032353                -0.476864
# 9       None                 -0.342510                -0.146613
# 10      None                 -0.555071                 0.230704
# 11      None                  0.198563                -0.144777
# 12      None                 -0.439384                 0.163317
# 13      None                 -0.852212                 3.532895
# 14      None                  0.245598                 0.257320
# 15      None                  0.508021                -0.088344
# T-Test Results:
#                                          t-statistic       p-value
# OPEC Cuts & Asian Economic Recovery       -23.017740  2.708379e-63
# Geopolitical Tensions                     -19.103329  4.868610e-51
# Hurricanes & Supply Disruptions            -8.628759  6.872953e-16
# Rising Demand & Speculation               -26.438642  7.545686e-74
# Financial Crisis                            9.778747  2.602026e-19
# Oil Price Crash                            22.816388  9.406352e-63
# Post-Crisis Recovery                      -25.564950  2.451723e-71
# Global Economic Recovery & BP Oil Spill   -27.208075  2.830226e-76
# ISIS insurgency in Iraq                    12.736641  5.985238e-29
# Oil Price Crash(2014)                      34.501844  7.557295e-97
# Continued Oversupply                       17.218588  2.396754e-44
# OPEC Production Cuts                       -9.388490  3.769456e-18
# Russia-Saudi Arabia oil price war          26.505305  7.756635e-75
# COVID-19 Pandemic                           8.603219  8.559213e-16
# OPEC+ production limits                   -14.198999  5.921297e-34
# Russia-Ukraine War                        -26.325212  4.970235e-74
