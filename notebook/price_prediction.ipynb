# %%
import pandas as pd
import sys,os
sys.path.append(os.path.abspath(os.path.join('..', 'scripts')))
from model import models
merged_data = pd.read_csv('../Data/features.csv')
model=models()

# %%
eng=model.feature_eng(merged_data)

# %%
train,validation,test=model.scale(eng)

# %%
model.var_model(train,test)
# Out:
# MSE: 311.00, RMSE: 17.64, MAE: 14.14
#                      GDP  Exchange Rate      Price
# 2020-06-28  8.703643e+13       0.824033  63.082104
# 2020-06-29  8.704933e+13       0.808790  63.124263
# 2020-06-30  8.706221e+13       0.800421  63.166437
# 2020-07-01  8.707506e+13       0.795801  63.208605
# 2020-07-02  8.708791e+13       0.793228  63.250755
# ...                  ...            ...        ...
# 2022-11-10  9.738655e+13       0.711995  90.621021
# 2022-11-11  9.739792e+13       0.711921  90.645165
# 2022-11-12  9.740929e+13       0.711848  90.669297
# 2022-11-13  9.742066e+13       0.711774  90.693416
# 2022-11-14  9.743203e+13       0.711701  90.717522
#
# [870 rows x 3 columns]

# %%
model.sarimax_model(train,test)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# MSE: 56.08, RMSE: 7.49, MAE: 5.62
# 2018-02-11    53.635187
# 2018-02-12    53.771587
# 2018-02-13    53.949795
# 2018-02-14    54.451999
# 2018-02-15    55.106874
#                 ...
# 2020-06-25    93.088857
# 2020-06-26    94.495532
# 2020-06-27    94.566606
# 2020-06-28    94.896857
# 2020-06-29    92.554004
# Freq: D, Name: predicted_mean, Length: 870, dtype: float64

# %%
model.ltsm(train,validation,test)
# Out:
# Epoch 1/50
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0134 - val_loss: 0.0018
# Epoch 2/50
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 3.7298e-04 - val_loss: 0.0017
# Epoch 3/50
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 3.2782e-04 - val_loss: 0.0012
# Epoch 4/50
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 2.8336e-04 - val_loss: 0.0011
# Epoch 5/50
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 2.5742e-04 - val_loss: 0.0011
# Epoch 6/50
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 2.3942e-04 - val_loss: 9.0474e-04
# Epoch 7/50
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 1.9603e-04 - val_loss: 7.1058e-04
# Epoch 8/50
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 2.0792e-04 - val_loss: 8.0711e-04
# Epoch 9/50
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 2.2188e-04 - val_loss: 6.7385e-04
# Epoch 10/50
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 1.8938e-04 - val_loss: 6.4862e-04
# Epoch 11/50
# ...
